# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0           0             0       SpaceX
# 1           1             1         CASC
# 2           2             2       SpaceX
# 3           3             3    Roscosmos
# 4           4             4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4324 non-null   int64
#  1   Unnamed: 0.1    4324 non-null   int64
#  2   Company Name    4324 non-null   object
#  3   Location        4324 non-null   object
#  4   Datum           4324 non-null   object
#  5   Detail          4324 non-null   object
#  6   Status Rocket   4324 non-null   object
#  7    Rocket         964 non-null    object
#  8   Status Mission  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB

# %%
df.drop([" Rocket","Unnamed: 0","Unnamed: 0.1"],axis=1,inplace=True)

# %%
df["Country"]=df["Location"].apply(lambda x:x.split()[-1])

# %% [markdown]
# # Top 3 Countries of Launches

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Country',data=df,order=df["Country"].value_counts().iloc[:3].index,palette='husl')
plt.ylabel('')
plt.xticks(fontsize=20,fontweight=1000)
plt.yticks(fontsize=20)
plt.xlabel('Countries',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# # Top Companies in Launches

# %%
df["Company Name"].value_counts().head()
# Out:
# RVSN USSR           1777
# Arianespace          279
# General Dynamics     251
# CASC                 251
# NASA                 203
# Name: Company Name, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(y='Company Name',data=df,order=df["Company Name"].value_counts().iloc[:5].index,palette='rainbow')
plt.xticks(fontsize=20,fontweight=1000)
plt.yticks(fontsize=20)
plt.ylabel('',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# # Ratio of Success Missions

# %%
df["Status Mission"].value_counts()
# Out:
# Success              3879
# Failure               339
# Partial Failure       102
# Prelaunch Failure       4
# Name: Status Mission, dtype: int64

# %%
plt.rcParams['font.size'] = 15.0
plt.figure(figsize=(12,12))
labels = 'Success', 'Failure', 'Partial Failure', 'Prelaunch Failure'
sizes = [3879, 339, 102, 4]
explode = (0, 0, 0, 0.1)
plt.pie(sizes,explode,labels)
plt.show()
